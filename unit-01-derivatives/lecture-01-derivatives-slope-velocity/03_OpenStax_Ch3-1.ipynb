# %% [markdown]
# # OpenStax Calculus Volume 1
#
# ## Chapter 3.1: Defining the Derivative
#
# ---

# %%
import sys
sys.path.append('../../../utils')
from calculus_utils import *
from plotting_utils import *
import sympy as sp
x = sp.Symbol('x')
print('✓ OpenStax Ch 3.1 Ready')

# %% [markdown]
# ## Learning Objectives
#
# 1. Recognize the meaning of tangent to a curve
# 2. Calculate slope of tangent line
# 3. Identify derivative as limit of difference quotient
# 4. Calculate derivative at a point
# 5. Describe velocity as rate of change
# 6. Explain average vs instantaneous velocity
