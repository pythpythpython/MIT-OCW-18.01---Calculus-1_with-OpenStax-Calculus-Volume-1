# %% [markdown]
# # OpenStax Calculus Volume 1
#
# ## Chapter 3.2: The Derivative as a Function
#
# ---

# %%
import sys
sys.path.append('../../../utils')
from calculus_utils import *
from plotting_utils import *
import sympy as sp
x = sp.Symbol('x')
print('✓ OpenStax Ch 3.2 Ready')

# %% [markdown]
# ## Learning Objectives
#
# 1. Define the derivative function
# 2. Graph a derivative from a function graph
# 3. State connection between derivatives and continuity
# 4. Describe when derivatives don't exist
# 5. Explain higher-order derivatives
