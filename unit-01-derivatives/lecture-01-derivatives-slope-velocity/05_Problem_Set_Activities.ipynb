# %% [markdown]
# # Lecture 1: Problem Set Activities
#
# ## Practice Problems with Solutions
#
# ---

# %%
import sys
sys.path.append('../../../utils')
from calculus_utils import *
from plotting_utils import *
import sympy as sp
x, h, a = sp.symbols('x h a')
print('✓ Problem Set Ready')

# %% [markdown]
# ## Problem 1: Find the Derivative from Definition
#
# **Problem**: Use the limit definition to find $f'(x)$ for $f(x) = x^2 + 3x$.
