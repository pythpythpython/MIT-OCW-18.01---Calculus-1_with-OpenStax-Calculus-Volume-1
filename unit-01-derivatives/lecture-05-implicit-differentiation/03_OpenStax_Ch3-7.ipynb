# %% [markdown]
# # OpenStax Section 3.7
#
# Comprehensive coverage of OpenStax Calculus Volume 1, Section 3.7

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy import *
import sys
sys.path.append('../../utils')
from calculus_utils import *
from plotting_utils import *

# Initialize pretty printing
sp.init_printing(use_latex='mathjax')

# Matplotlib settings
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Definitions

# %% [markdown]
# ## Theorems

# %% [markdown]
# ## Worked Examples

# %% [markdown]
# ## Exercises
