# %% [markdown]
# # Lecture 10: Curve Sketching - Overview
#
# Master dashboard for tracking progress through Lecture 10

# %% [markdown]
# ## Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from sympy import *
import sys
sys.path.append('../../utils')
from calculus_utils import *
from plotting_utils import *

# Initialize pretty printing
sp.init_printing(use_latex='mathjax')

# Matplotlib settings
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# ## Learning Objectives
#
# 1. [Add objective here]

# %% [markdown]
# ## Prerequisites
#
# - [ ] [Add prerequisite here]

# %% [markdown]
# ## Resources
#
# - [Link to resource]

# %% [markdown]
# ## Progress Tracker
#
# - [ ] Lecture notes reviewed
# - [ ] Textbook sections completed
# - [ ] Problems attempted
